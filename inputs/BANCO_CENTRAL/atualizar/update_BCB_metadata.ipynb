# %%
import pandas as pd
import requests
from datetime import datetime

# Caminho do arquivo CSV atualizado
file_path = 'BCB_metadata_atualizado.csv'
output_file = 'BCB_metadata_atualizado.csv'

# Carregar o arquivo de metadados já preenchido
metadata_df = pd.read_csv(file_path, sep=',', quotechar='"', on_bad_lines='skip')

# Renomear as colunas em português, caso necessário
metadata_df.rename(columns={
    'code': 'código',
    'name': 'nome',
    'description': 'descrição',
    'refreshed_at': 'atualizado_em'
}, inplace=True, errors='ignore')

# Função para separar "Units: " da descrição
def extrair_unidade(description):
    if "Units: " in description:
        unidade = description.split("Units: ")[1].strip()
        descricao_atualizada = description.split("Units: ")[0].strip()
        return descricao_atualizada, unidade
    return description, None

# Função para consultar a série na API do Banco Central
def baixar_dados_serie(codigo):
    url = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{codigo}/dados?formato=json'
    try:
        response = requests.get(url)
        response.raise_for_status()  # Verifica se houve algum erro de resposta HTTP
        dados = response.json()
        return dados, "Sucesso"
    except requests.exceptions.RequestException as e:
        return None, f"Erro de requisição: {e}"
    except ValueError:
        return None, "Erro ao decodificar JSON"
    except Exception as e:
        return None, f"Erro desconhecido: {e}"

# Função para calcular a frequência com base nas datas
def calcular_frequencia(primeira_data, ultima_data, num_registros):
    delta = (ultima_data - primeira_data).days
    if delta == 0:
        return None, "Indeterminado"
    
    media_frequencia = delta / num_registros
    
    if media_frequencia < 10:
        return media_frequencia, "Diária"
    elif media_frequencia < 20:
        return media_frequencia, "Quinzenal"
    elif media_frequencia < 40:
        return media_frequencia, "Mensal"
    else:
        return media_frequencia, "Indeterminado"

# Função para verificar se a série está ativa ou inativa
def verificar_atividade(ultima_data):
    hoje = datetime.today()
    delta_meses = (hoje.year - ultima_data.year) * 12 + hoje.month - ultima_data.month
    return "Ativa" if delta_meses < 2 else "Inativa"

# Função para atualizar os metadados
def atualizar_metadados(codigo_serie):
    try:
        dados, status_download = baixar_dados_serie(codigo_serie)
        if not dados:
            return None, status_download
        
        # Extrair informações relevantes
        df = pd.DataFrame(dados)
        df['data'] = pd.to_datetime(df['data'], format='%d/%m/%Y')
        df['valor'] = pd.to_numeric(df['valor'], errors='coerce')
        
        primeira_data = df['data'].min()
        ultima_data = df['data'].max()
        num_registros = df.shape[0]
        valor_min = df['valor'].min()
        valor_max = df['valor'].max()
        media_valor = df['valor'].mean()
        desvio_padrao_valor = df['valor'].std()

        # Calcular a frequência e verificar se a série está ativa
        media_frequencia, frequencia = calcular_frequencia(primeira_data, ultima_data, num_registros)
        status_atividade = verificar_atividade(ultima_data)
        
        # Calcular intervalo em dias após a última data
        intervalo_dias = (datetime.today() - ultima_data).days

        return {
            'num_registros': num_registros,
            'primeira_data': primeira_data,
            'ultima_data': ultima_data,
            'intervalo_dias': intervalo_dias,
            'valor_min': valor_min,
            'valor_max': valor_max,
            'media_valor': media_valor,
            'desvio_padrao_valor': desvio_padrao_valor,
            'media_frequencia': media_frequencia,
            'frequencia': frequencia,
            'status_atividade': status_atividade,
            'status_download': status_download
        }, status_download
    except Exception as e:
        return None, f"Erro durante o processamento: {e}"

# Verificar e atualizar apenas os registros que estão incompletos
for index, row in metadata_df.iterrows():
    # Verificar se o campo 'num_registros' está preenchido, caso contrário, atualizar a série
    if pd.isna(row['num_registros']) or pd.isna(row['ultima_data']):
        codigo_serie = row['código']
        
        # Separar "Unidade" da descrição, se ainda não tiver sido separada
        if pd.isna(row.get('Unidade', None)):
            descricao_atualizada, unidade = extrair_unidade(row['descrição'])
            metadata_df.loc[index, 'descrição'] = descricao_atualizada
            metadata_df.loc[index, 'Unidade'] = unidade

        # Atualizar timestamp do momento da verificação
        metadata_df.loc[index, 'atualizado_em'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

        # Imprimir os detalhes da série em uma única linha
        print(f"Código: {codigo_serie}, Nome: {row['nome'][:50]}", end="")  # Limita o nome para 50 caracteres para manter a linha compacta

        metadados, status = atualizar_metadados(codigo_serie)
        
        # Atualizar o status, independentemente de sucesso ou erro
        metadata_df.loc[index, 'status_download'] = status
        
        if metadados:
            metadata_df.loc[index, 'num_registros'] = metadados['num_registros']
            metadata_df.loc[index, 'primeira_data'] = metadados['primeira_data']
            metadata_df.loc[index, 'ultima_data'] = metadados['ultima_data']
            metadata_df.loc[index, 'intervalo_dias'] = metadados['intervalo_dias']
            metadata_df.loc[index, 'valor_min'] = metadados['valor_min']
            metadata_df.loc[index, 'valor_max'] = metadados['valor_max']
            metadata_df.loc[index, 'media_valor'] = metadados['media_valor']
            metadata_df.loc[index, 'desvio_padrao_valor'] = metadados['desvio_padrao_valor']
            metadata_df.loc[index, 'media_frequencia'] = metadados['media_frequencia']
            metadata_df.loc[index, 'frequencia'] = metadados['frequencia']
            metadata_df.loc[index, 'status_atividade'] = metadados['status_atividade']
            
            # Completar a linha com as datas e o status
            print(f", de: {metadados['primeira_data']}, a: {metadados['ultima_data']}, Registros: {metadados['num_registros']}, Status: {status}")
        else:
            # Se houve erro, mostrar o status de falha
            print(f", Registros: 0, Status: {status}")
        
        # Salvar o arquivo atualizado a cada iteração, mesmo que tenha ocorrido erro
        metadata_df.to_csv(output_file, index=False)

# Exibir a mensagem final
print("Processo concluído e metadados atualizados.")
# Out:
# Código: 10419, Nome: FDI - United Kingdom - Manufacture of metal produc, Registros: 0, Status: Sucesso
# Código: 10789, Nome: FDI - Uruguay - Manufacture of medical, precision , Registros: 0, Status: Sucesso
# Código: 10838, Nome: FDI - Bermuda - Manufacture of metal products, Registros: 0, Status: Sucesso
# Código: 10854, Nome: FDI - Bermuda - Manufacture of metal products, Registros: 0, Status: Sucesso
# Código: 10859, Nome: FDI - Panama - Manufacture of cellulose, paper and, Registros: 0, Status: Erro de requisição: Expecting value: line 1 column 1 (char 0)
# Código: 10861, Nome: FDI - Bermuda - Manufacture of medical, precision , Registros: 0, Status: Sucesso
# Código: 10865, Nome: FDI - Chile - Manufacture of non-metallic mineral , Registros: 0, Status: Sucesso
# Código: 10869, Nome: FDI - Gibraltar - Manufacture of wood products, Registros: 0, Status: Sucesso
# Código: 10879, Nome: FDI - Singapore - Manufacture of cellulose, paper , Registros: 0, Status: Sucesso
# Código: 10880, Nome: FDI - Singapore - Manufacture of cellulose, paper , Registros: 0, Status: Sucesso
# Código: 10882, Nome: FDI - Denmark - Manufacture of metal products, Registros: 0, Status: Sucesso
# Código: 10887, Nome: FDI - South Africa - Data processing and related a, Registros: 0, Status: Sucesso
# Código: 10894, Nome: FDI - Antigua and Barbuda - Manufacture of machine, Registros: 0, Status: Sucesso
# Código: 10896, Nome: FDI - Netherlands Antilles - Financial intermediat, Registros: 0, Status: Sucesso
# Código: 10899, Nome: FDI - Argentina - Production of coke, petroleum, n, Registros: 0, Status: Sucesso
# Código: 10902, Nome: FDI - Aruba - Commerce and repair of motor vehicle, Registros: 0, Status: Sucesso
# Código: 10904, Nome: FDI - Australia - Transportation ancillary activit, Registros: 0, Status: Sucesso
# Código: 10907, Nome: FDI - Austria - Manufacture of other transportatio, Registros: 0, Status: Sucesso
# Código: 10910, Nome: FDI - Bahamas, the - Health and social services, Registros: 0, Status: Sucesso
# Código: 10911, Nome: FDI - Barbados - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 10912, Nome: FDI - Belgium - Manufacture of furniture and other, Registros: 0, Status: Sucesso
# Código: 10913, Nome: FDI - Belgium - Manufacture of textiles, Registros: 0, Status: Sucesso
# Código: 10914, Nome: FDI - Belgium - Research and development, Registros: 0, Status: Sucesso
# Código: 10915, Nome: FDI - Belize - Total, Registros: 0, Status: Sucesso
# Código: 10916, Nome: FDI - Belize - Real estate activities, Registros: 0, Status: Sucesso
# Código: 10917, Nome: FDI - Belize - Land transportation, Registros: 0, Status: Sucesso
# Código: 10919, Nome: FDI - Canada - Fishing, water farming and related , Registros: 0, Status: Sucesso
# Código: 10921, Nome: FDI - Cayman islands - Forestry, forest exploratio, Registros: 0, Status: Sucesso
# Código: 10928, Nome: FDI - Cyprus - Data processing and related activit, Registros: 0, Status: Sucesso
# Código: 10929, Nome: FDI - Singapore - Eletricity, gas and hot water, Registros: 0, Status: Sucesso
# Código: 10935, Nome: FDI - Cuba - Wholesale and commerce intermediation, Registros: 0, Status: Sucesso
# Código: 10937, Nome: FDI - Denmark - Eletricity, gas and hot water, Registros: 0, Status: Sucesso
# Código: 10942, Nome: FDI - Slovak, Republic - Total, Registros: 0, Status: Sucesso
# Código: 10943, Nome: FDI - Slovak, Republic - Commerce and repair of mo, Registros: 0, Status: Sucesso
# Código: 10946, Nome: FDI - Spain - Preparation of leather and articles , Registros: 0, Status: Sucesso
# Código: 10947, Nome: FDI - Spain - Personal services, Registros: 0, Status: Sucesso
# Código: 10949, Nome: FDI - United States - Recycling, Registros: 0, Status: Sucesso
# Código: 10952, Nome: FDI - France - Manufacture of medical, precision a, Registros: 0, Status: Sucesso
# Código: 10954, Nome: FDI - Gibraltar - Agriculture, livestock and relat, Registros: 0, Status: Sucesso
# Código: 10956, Nome: FDI - Gibraltar - Transportation ancillary activit, Registros: 0, Status: Sucesso
# Código: 10958, Nome: FDI - Gibraltar - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 10961, Nome: FDI - Hong Kong - Manufacture of wood products, Registros: 0, Status: Sucesso
# Código: 10963, Nome: FDI - Hungary - Mail and telecommunications, Registros: 0, Status: Sucesso
# Código: 10967, Nome: FDI - Indonesia - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 10969, Nome: FDI - Islandia - Total, Registros: 0, Status: Sucesso
# Código: 10970, Nome: FDI - Islandia - Fishing, water farming and relate, Registros: 0, Status: Sucesso
# Código: 10971, Nome: FDI - Islandia - Services redered to companies, Registros: 0, Status: Sucesso
# Código: 10974, Nome: FDI - Israel - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 10983, Nome: FDI - Leeward - Manufacture of rubber and plastic , Registros: 0, Status: Sucesso
# Código: 10993, Nome: FDI - Liechtenstein - Manufacture of other transpo, Registros: 0, Status: Sucesso
# Código: 10995, Nome: FDI - Luxembourg - Urban cleaning, sewer and relat, Registros: 0, Status: Sucesso
# Código: 10998, Nome: FDI - Mauritius - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 11000, Nome: FDI - Nicaragua - Total, Registros: 0, Status: Sucesso
# Código: 11001, Nome: FDI - Nicaragua - Services redered to companies, Registros: 0, Status: Sucesso
# Código: 11004, Nome: FDI - Panama - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11007, Nome: FDI - Panama - Preparation of leather and articles, Registros: 0, Status: Sucesso
# Código: 11008, Nome: FDI - Panama - Water transportation, Registros: 0, Status: Sucesso
# Código: 11010, Nome: FDI - Paraguay - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11012, Nome: FDI - Paraguay - Manufacture of non-metallic miner, Registros: 0, Status: Sucesso
# Código: 11014, Nome: FDI - Peru - Manufacture of machines and equipment, Registros: 0, Status: Sucesso
# Código: 11016, Nome: FDI - Poland - Services redered to companies, Registros: 0, Status: Sucesso
# Código: 11018, Nome: FDI - Puerto Rico - Personal services, Registros: 0, Status: Sucesso
# Código: 11020, Nome: FDI - United Kingdom - Making of garments and acce, Registros: 0, Status: Sucesso
# Código: 11021, Nome: FDI - United Kingdom - Coal mining, Registros: 0, Status: Sucesso
# Código: 11028, Nome: FDI - Sirya - Total, Registros: 0, Status: Sucesso
# Código: 11029, Nome: FDI - Sirya - Publishing, printing and reproductio, Registros: 0, Status: Sucesso
# Código: 11030, Nome: FDI - Sweden - Agriculture, livestock and related , Registros: 0, Status: Sucesso
# Código: 11033, Nome: FDI - Switzerland - Publishing, printing and repro, Registros: 0, Status: Sucesso
# Código: 11034, Nome: FDI - Switzerland - Petroleum extraction and relat, Registros: 0, Status: Sucesso
# Código: 11035, Nome: FDI - Switzerland - Manufacture of other transport, Registros: 0, Status: Sucesso
# Código: 11036, Nome: FDI - Uruguay - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11093, Nome: FDI - China, People's Republic of - Mail and telec, Registros: 0, Status: Sucesso
# Código: 11094, Nome: FDI - South Korea - Urban cleaning, sewer and rela, Registros: 0, Status: Sucesso
# Código: 11100, Nome: FDI - Hong Kong - Commerce and repair of motor veh, Registros: 0, Status: Sucesso
# Código: 11102, Nome: FDI - Israel - Manufacture of other transportation, Registros: 0, Status: Sucesso
# Código: 11127, Nome: FDI - Luxembourg - Agriculture, livestock and rela, Registros: 0, Status: Sucesso
# Código: 11130, Nome: FDI - Peru - Manufacture of eletric machines, appa, Registros: 0, Status: Sucesso
# Código: 11133, Nome: FDI - Sweden - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11140, Nome: FDI - Luxembourg - Manufacture of cellulose, paper, Registros: 0, Status: Sucesso
# Código: 11142, Nome: FDI - New Zealand - Manufacture of cellulose, pape, Registros: 0, Status: Sucesso
# Código: 11146, Nome: FDI - Australia - Data processing and related acti, Registros: 0, Status: Sucesso
# Código: 11147, Nome: FDI - Bolivia - Construction, Registros: 0, Status: Sucesso
# Código: 11149, Nome: FDI - Italy - Health and social services, Registros: 0, Status: Erro de requisição: Expecting value: line 1 column 1 (char 0)
# Código: 11150, Nome: FDI - Luxembourg - Manufacture of cellulose, paper, Registros: 0, Status: Sucesso
# Código: 11153, Nome: FDI - Switzerland - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11159, Nome: FDI - Austria - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 11162, Nome: FDI - Cayman islands - Publishing, printing and re, Registros: 0, Status: Sucesso
# Código: 11166, Nome: FDI - Taiwan - Manufacture of rubber and plastic a, Registros: 0, Status: Sucesso
# Código: 11176, Nome: FDI - Morocco - Total, Registros: 0, Status: Sucesso
# Código: 11184, Nome: FDI - Angola - Construction, Registros: 0, Status: Sucesso
# Código: 11185, Nome: FDI - Austria - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 11188, Nome: FDI - Cayman islands - Publishing, printing and re, Registros: 0, Status: Sucesso
# Código: 11189, Nome: FDI - China, People's Republic of - Manufacture an, Registros: 0, Status: Sucesso
# Código: 11191, Nome: FDI - Taiwan - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11200, Nome: FDI - Leeward - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11203, Nome: FDI - Panama - Personal services, Registros: 0, Status: Sucesso
# Código: 11204, Nome: FDI - Chile - Transportation ancillary activities , Registros: 0, Status: Sucesso
# Código: 11206, Nome: FDI - Chile - Transportation ancillary activities , Registros: 0, Status: Sucesso
# Código: 11210, Nome: FDI - Ireland - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11213, Nome: FDI - Japan - Education, Registros: 0, Status: Sucesso
# Código: 11219, Nome: FDI - Hong-Kong - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11220, Nome: FDI - Ireland - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11221, Nome: FDI - Israel - Manufacture of rubber and plastic a, Registros: 0, Status: Sucesso
# Código: 11223, Nome: FDI - Japan - Education, Registros: 0, Status: Sucesso
# Código: 11224, Nome: FDI - Norway - Transportation ancillary activities, Registros: 0, Status: Sucesso
# Código: 11225, Nome: FDI - French guiana - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11226, Nome: FDI - Sweden - Land transportation, Registros: 0, Status: Sucesso
# Código: 11227, Nome: FDI - Saudi Arabia - Total, Registros: 0, Status: Sucesso
# Código: 11228, Nome: FDI - Saudi Arabia - Agriculture, livestock and re, Registros: 0, Status: Sucesso
# Código: 11230, Nome: FDI - Austria - Construction, Registros: 0, Status: Sucesso
# Código: 11233, Nome: FDI - Cayman islands - Personal services, Registros: 0, Status: Sucesso
# Código: 11236, Nome: FDI - Philippines - Data processing and related ac, Registros: 0, Status: Sucesso
# Código: 11237, Nome: FDI - Taiwan - Fishing, water farming and related , Registros: 0, Status: Sucesso
# Código: 11241, Nome: FDI - Monaco - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11242, Nome: FDI - Netherlands - Manufacture of medical, precis, Registros: 0, Status: Sucesso
# Código: 11243, Nome: FDI - Panama - Manufacture of textiles, Registros: 0, Status: Sucesso
# Código: 11245, Nome: FDI - Switzerland - Preparation of leather and art, Registros: 0, Status: Sucesso
# Código: 11246, Nome: FDI - Uruguay - Water transportation, Registros: 0, Status: Sucesso
# Código: 11248, Nome: FDI - Saudi Arabia - Agriculture, livestock and re, Registros: 0, Status: Sucesso
# Código: 11252, Nome: FDI - Canada - Manufacture of non-metallic mineral, Registros: 0, Status: Sucesso
# Código: 11253, Nome: FDI - Cayman islands - Personal services, Registros: 0, Status: Sucesso
# Código: 11258, Nome: FDI - Hong Kong - Manufacture of other transportat, Registros: 0, Status: Sucesso
# Código: 11259, Nome: FDI - Hungary - Services redered to companies, Registros: 0, Status: Sucesso
# Código: 11262, Nome: FDI - Liechtenstein - Petroleum extraction and rel, Registros: 0, Status: Sucesso
# Código: 11265, Nome: FDI - Panama - Manufacture of textiles, Registros: 0, Status: Sucesso
# Código: 11266, Nome: FDI - Dominican Republic - Transportation ancillar, Registros: 0, Status: Sucesso
# Código: 11268, Nome: FDI - Uruguay - Water transportation, Registros: 0, Status: Sucesso
# Código: 11271, Nome: FDI -Argentina - Education, Registros: 0, Status: Sucesso
# Código: 11272, Nome: FDI - Austria - Transportation ancillary activitie, Registros: 0, Status: Sucesso
# Código: 11274, Nome: FDI - Belgium - Fishing, water farming and related, Registros: 0, Status: Sucesso
# Código: 11276, Nome: FDI - Canada - Personal services, Registros: 0, Status: Sucesso
# Código: 11277, Nome: FDI - Canal islands - Wholesale and commerce inter, Registros: 0, Status: Sucesso
# Código: 11278, Nome: FDI - Cayman islands - Air transportation, Registros: 0, Status: Sucesso
# Código: 11279, Nome: FDI - Chile - Agriculture, livestock and related s, Registros: 0, Status: Sucesso
# Código: 11280, Nome: FDI - Chile - Recreational, cultural and sport act, Registros: 0, Status: Sucesso
# Código: 11282, Nome: FDI - Chile - Fishing, water farming and related s, Registros: 0, Status: Sucesso
# Código: 11283, Nome: FDI - China - Transportation ancillary activities , Registros: 0, Status: Sucesso
# Código: 11285, Nome: FDI - Singapore - Manufacture of other transportat, Registros: 0, Status: Sucesso
# Código: 11286, Nome: FDI - Colombia - Manufacture of other transportati, Registros: 0, Status: Sucesso
# Código: 11287, Nome: FDI - South Korea - Making of garments and accesso, Registros: 0, Status: Sucesso
# Código: 11288, Nome: FDI - Denmark - Transportation ancillary activitie, Registros: 0, Status: Sucesso
# Código: 11289, Nome: FDI - Denmark - Real estate activities, Registros: 0, Status: Erro de requisição: Expecting value: line 1 column 1 (char 0)
# Código: 11290, Nome: FDI - Denmark - Water transportation, Registros: 0, Status: Sucesso
# Código: 11291, Nome: FDI - United Arab Emirates - Accomodation and cate, Registros: 0, Status: Sucesso
# Código: 11292, Nome: FDI - Slovenia, republic of - Manufacture of furni, Registros: 0, Status: Sucesso
# Código: 11294, Nome: FDI - Finland - Manufacture of metal products, Registros: 0, Status: Sucesso
# Código: 11295, Nome: FDI - Taiwan - Commerce and repair of motor vehicl, Registros: 0, Status: Sucesso
# Código: 11296, Nome: FDI - Taiwan - Manufacture of chemical products, Registros: 0, Status: Sucesso
# Código: 11297, Nome: FDI - France - Education, Registros: 0, Status: Sucesso
# Código: 11298, Nome: FDI - Guatemala - Agriculture, livestock and relat, Registros: 0, Status: Sucesso
# Código: 11299, Nome: FDI - Israel - Manufacture of eletronic materials , Registros: 0, Status: Sucesso
# Código: 11302, Nome: FDI - Leeward - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11303, Nome: FDI - Lebanon - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11304, Nome: FDI - Liechtenstein - Manufacture of eletric machi, Registros: 0, Status: Sucesso
# Código: 11305, Nome: FDI - Liechtenstein - Manufacture of metal product, Registros: 0, Status: Sucesso
# Código: 11307, Nome: FDI - Liechtenstein - Forestry, forest exploration, Registros: 0, Status: Sucesso
# Código: 11309, Nome: FDI - Luxembourg - Manufacture of medical, precisi, Registros: 0, Status: Sucesso
# Código: 11310, Nome: FDI - Mexico - Agriculture, livestock and related , Registros: 0, Status: Sucesso
# Código: 11311, Nome: FDI - Mexico - Construction, Registros: 0, Status: Sucesso
# Código: 11312, Nome: FDI - Monaco - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 11314, Nome: FDI - Netherlands - Research and development, Registros: 0, Status: Sucesso
# Código: 11315, Nome: FDI - Panama - Making of garments and accessoires, Registros: 0, Status: Sucesso
# Código: 11317, Nome: FDI - Pakistan - Total, Registros: 0, Status: Sucesso
# Código: 11318, Nome: FDI - Pakistan - Wholesale and commerce intermedia, Registros: 0, Status: Sucesso
# Código: 11319, Nome: FDI - Paraguay - Manufacture of furniture and othe, Registros: 0, Status: Sucesso
# Código: 11320, Nome: FDI - Portugal - Manufacture of cellulose, paper a, Registros: 0, Status: Sucesso
# Código: 11321, Nome: FDI - Russia - Commerce and repair of motor vehicl, Registros: 0, Status: Sucesso
# Código: 11322, Nome: FDI - St.Vincent and Grenadines - Total, Registros: 0, Status: Sucesso
# Código: 11323, Nome: FDI - St.Vincent and Grenadines - Agriculture, liv, Registros: 0, Status: Sucesso
# Código: 11324, Nome: FDI - Sweden - Transportation ancillary activities, Registros: 0, Status: Sucesso
# Código: 11326, Nome: FDI - Turkey - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11327, Nome: FDI - Venezuela - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 11328, Nome: FDI - Venezuela - Construction, Registros: 0, Status: Sucesso
# Código: 11329, Nome: FDI - Venezuela - Publishing, printing and reprodu, Registros: 0, Status: Sucesso
# Código: 11330, Nome: FDI - Venezuela - Manufacture of machines and equi, Registros: 0, Status: Sucesso
# Código: 11331, Nome: FDI - Argentina - Forestry, forest exploration and, Registros: 0, Status: Sucesso
# Código: 11334, Nome: FDI - Austria - Manufacture of non-metallic minera, Registros: 0, Status: Sucesso
# Código: 11335, Nome: FDI - Cape Verde, Republic of - Wholesale and comm, Registros: 0, Status: Sucesso
# Código: 11337, Nome: FDI - Cayman islands - Production of coke, petrole, Registros: 0, Status: Sucesso
# Código: 11338, Nome: FDI - Chile - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11343, Nome: FDI - Indonesia - Wholesale and commerce intermedi, Registros: 0, Status: Sucesso
# Código: 11344, Nome: FDI - Indonesia - Data processing and related acti, Registros: 0, Status: Sucesso
# Código: 11345, Nome: FDI - Indonesia - Total, Registros: 0, Status: Sucesso
# Código: 11350, Nome: FDI - Luxembourg - Commerce and repair of motor ve, Registros: 0, Status: Sucesso
# Código: 11351, Nome: FDI - Panama - Education, Registros: 0, Status: Sucesso
# Código: 11354, Nome: FDI - Saint Lucia - Wholesale and commerce interme, Registros: 0, Status: Sucesso
# Código: 11356, Nome: FDI - Sweden - Manufacture of eletronic materials , Registros: 0, Status: Sucesso
# Código: 11358, Nome: FDI - Romania - Wholesale and commerce intermediat, Registros: 0, Status: Sucesso
# Código: 11359, Nome: FDI - Romania - Total, Registros: 0, Status: Sucesso
# Código: 11365, Nome: FDI - Hong Kong - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 11366, Nome: FDI - Hungary - Manufacture of eletronic materials, Registros: 0, Status: Sucesso
# Código: 11367, Nome: FDI - Netherlands - Manufacture of tobacco product, Registros: 0, Status: Sucesso
# Código: 11369, Nome: FDI - United kingdom - Forestry, forest exploratio, Registros: 0, Status: Sucesso
# Código: 11372, Nome: FDI - Barbados - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11373, Nome: FDI - Canada - Manufacture of cellulose, paper and, Registros: 0, Status: Sucesso
# Código: 11374, Nome: FDI - Canal islands - Manufacture of rubber and pl, Registros: 0, Status: Sucesso
# Código: 11375, Nome: FDI - Canal islands - Manufacture and assembly of , Registros: 0, Status: Sucesso
# Código: 11376, Nome: FDI - Cook Islands - Petroleum extraction and rela, Registros: 0, Status: Sucesso
# Código: 11380, Nome: FDI - France - Forestry, forest exploration and re, Registros: 0, Status: Sucesso
# Código: 11383, Nome: FDI - New Zealand - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11385, Nome: FDI - Venezuela - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 11793, Nome: FDI - Canada - Eletricity, gas and hot water, Registros: 0, Status: Sucesso
# Código: 11794, Nome: FDI - Cayman islands - Recycling, Registros: 0, Status: Sucesso
# Código: 11796, Nome: FDI - Cyprus - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11797, Nome: FDI - Colombia - Data processing and related activ, Registros: 0, Status: Sucesso
# Código: 11799, Nome: FDI - Liberia - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11801, Nome: FDI - Germany - Fishing, water farming and related, Registros: 0, Status: Sucesso
# Código: 11802, Nome: FDI - Netherlands antilles - Agriculture, livestoc, Registros: 0, Status: Sucesso
# Código: 11805, Nome: FDI - Hong Kong - Data processing and related acti, Registros: 0, Status: Sucesso
# Código: 11807, Nome: FDI - Japan - Land transportation, Registros: 0, Status: Sucesso
# Código: 11808, Nome: FDI - Latvia - Transportation ancillary activities, Registros: 0, Status: Sucesso
# Código: 11809, Nome: FDI - Latvia - Total, Registros: 0, Status: Sucesso
# Código: 11814, Nome: FDI - Canada - Commerce and repair of motor vehicl, Registros: 0, Status: Sucesso
# Código: 11817, Nome: FDI - Denmark - Insurance and private social secur, Registros: 0, Status: Sucesso
# Código: 11818, Nome: FDI - Hong-Kong - Water transportation, Registros: 0, Status: Sucesso
# Código: 11819, Nome: FDI - Hungary - Manufacture of medical, precision , Registros: 0, Status: Sucesso
# Código: 11820, Nome: FDI - Japan - Recycling, Registros: 0, Status: Sucesso
# Código: 11823, Nome: FDI - Luxembourg - Preparation of leather and arti, Registros: 0, Status: Sucesso
# Código: 11825, Nome: FDI - Germany - Education, Registros: 0, Status: Sucesso
# Código: 11827, Nome: FDI - Aruba - Wholesale and commerce intermediatio, Registros: 0, Status: Sucesso
# Código: 11828, Nome: FDI - Aruba - Total, Registros: 0, Status: Sucesso
# Código: 11830, Nome: FDI - Austria - Manufacture of food and beverages, Registros: 0, Status: Sucesso
# Código: 11831, Nome: FDI - China, people's republic of - Manufacture of, Registros: 0, Status: Sucesso
# Código: 11832, Nome: FDI - Colombia - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11833, Nome: FDI - Hungary - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 11834, Nome: FDI - Israel - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11837, Nome: FDI - Panama - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11839, Nome: FDI - Poland - Wholesale and commerce intermediati, Registros: 0, Status: Sucesso
# Código: 11846, Nome: FDI - Germany - Fishing, water farming and related, Registros: 0, Status: Sucesso
# Código: 11848, Nome: FDI - Angola - Fishing, water farming and related , Registros: 0, Status: Sucesso
# Código: 11850, Nome: FDI - Antigua and Barbuda - Construction, Registros: 0, Status: Sucesso
# Código: 11853, Nome: FDI - Argentina - Personal services, Registros: 0, Status: Sucesso
# Código: 11854, Nome: FDI - Australia - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11857, Nome: FDI - Australia - Manufacture of machines and equi, Registros: 0, Status: Sucesso
# Código: 11858, Nome: FDI - Austria - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11860, Nome: FDI - Austria - Manufacture of food and beverages, Registros: 0, Status: Sucesso
# Código: 11864, Nome: FDI - Barbados - Extraction of non-metalic ores, Registros: 0, Status: Sucesso
# Código: 11866, Nome: FDI - Belgium - Manufacture of cellulose, paper an, Registros: 0, Status: Sucesso
# Código: 11870, Nome: FDI - Cape Verde, Republica of - Wholesale and com, Registros: 0, Status: Sucesso
# Código: 11871, Nome: FDI - Cape Verde, Republica of - Total, Registros: 0, Status: Sucesso
# Código: 11872, Nome: FDI - Canada - Commerce and repair of motor vehicl, Registros: 0, Status: Sucesso
# Código: 11873, Nome: FDI - Canada - Manufacture of cellulose, paper and, Registros: 0, Status: Sucesso
# Código: 11874, Nome: FDI - Canada - Manufacture of wood products, Registros: 0, Status: Sucesso
# Código: 11876, Nome: FDI - Canal islands - Manufacture of rubber and pl, Registros: 0, Status: Sucesso
# Código: 11877, Nome: FDI - Canal islands - Manufacture and assembly of , Registros: 0, Status: Sucesso
# Código: 11879, Nome: FDI - Cayman islands - Recycling, Registros: 0, Status: Sucesso
# Código: 11883, Nome: FDI - China, people's republic of - Manufacture of, Registros: 0, Status: Sucesso
# Código: 11887, Nome: FDI - Cyprus - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11888, Nome: FDI - Colombia - Data processing and related activ, Registros: 0, Status: Sucesso
# Código: 11889, Nome: FDI - Cook islands - Petroleum extraction and rela, Registros: 0, Status: Sucesso
# Código: 11890, Nome: FDI - South Korea - Transportation ancillary activ, Registros: 0, Status: Sucesso
# Código: 11891, Nome: FDI - South Korea - Urban cleaning, sewer and rela, Registros: 0, Status: Sucesso
# Código: 11892, Nome: FDI - Costa Rica - Wholesale and commerce intermed, Registros: 0, Status: Sucesso
# Código: 11894, Nome: FDI - Denmark - Manufacture of non-metallic minera, Registros: 0, Status: Sucesso
# Código: 11895, Nome: FDI - Denmark - Insurance and private social secur, Registros: 0, Status: Sucesso
# Código: 11898, Nome: FDI - Spain - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11900, Nome: FDI - United States - Production of coke, petroleu, Registros: 0, Status: Sucesso
# Código: 11905, Nome: FDI - Greece - Real estate activities, Registros: 0, Status: Sucesso
# Código: 11909, Nome: FDI - Hong-Kong - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11911, Nome: FDI - Hong-Kong - Data processing and related acti, Registros: 0, Status: Sucesso
# Código: 11913, Nome: FDI - Hong-Kong - Commerce and repair of motor veh, Registros: 0, Status: Sucesso
# Código: 11920, Nome: FDI - Hong-Kong - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 11922, Nome: FDI - Hong-Kong - Water transportation, Registros: 0, Status: Sucesso
# Código: 11924, Nome: FDI - Hungary - Retail and repair of articles, Registros: 0, Status: Sucesso
# Código: 11925, Nome: FDI - Hungary - Manufacture of medical, precision , Registros: 0, Status: Sucesso
# Código: 11927, Nome: FDI - Indonesia - Data processing and related acti, Registros: 0, Status: Sucesso
# Código: 11928, Nome: FDI - Ireland - Agriculture, livestock and related, Registros: 0, Status: Sucesso
# Código: 11931, Nome: FDI - Israel - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11932, Nome: FDI - Israel - Manufacture of other transportation, Registros: 0, Status: Sucesso
# Código: 11938, Nome: FDI - Italy - Water transportation, Registros: 0, Status: Sucesso
# Código: 11941, Nome: FDI - Jersey, Channel Islands - Manufacture of foo, Registros: 0, Status: Sucesso
# Código: 11947, Nome: FDI - Latvia - Transportation ancillary activities, Registros: 0, Status: Sucesso
# Código: 11948, Nome: FDI - Latvia - Total, Registros: 0, Status: Sucesso
# Código: 11950, Nome: FDI - Liberia - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11951, Nome: FDI - Liechtenstein - Publishing, printing and rep, Registros: 0, Status: Sucesso
# Código: 11953, Nome: FDI - Liechtenstein - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 11955, Nome: FDI - Luxembourg - Commerce and repair of motor ve, Registros: 0, Status: Sucesso
# Código: 11958, Nome: FDI - Luxembourg - Preparation of leather and arti, Registros: 0, Status: Sucesso
# Código: 11961, Nome: FDI - Marshall, Island - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 11966, Nome: FDI - New zealand - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11968, Nome: FDI - Netherlands - Manufacture of tobacco product, Registros: 0, Status: Sucesso
# Código: 11970, Nome: FDI - Panama - Education, Registros: 0, Status: Sucesso
# Código: 11971, Nome: FDI - Panama - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11972, Nome: FDI - Panama - Manufacture of food and beverages, Registros: 0, Status: Sucesso
# Código: 11975, Nome: FDI - Paraguay - Mail and telecommunications, Registros: 0, Status: Sucesso
# Código: 11976, Nome: FDI - Paraguay - Manufacture of rubber and plastic, Registros: 0, Status: Sucesso
# Código: 11977, Nome: FDI - Peru - Accomodation and catering, Registros: 0, Status: Sucesso
# Código: 11979, Nome: FDI - Poland - Wholesale and commerce intermediati, Registros: 0, Status: Sucesso
# Código: 11980, Nome: FDI - Poland - Manufacture of rubber and plastic a, Registros: 0, Status: Sucesso
# Código: 11983, Nome: FDI - Portugal - Extraction of ores, Registros: 0, Status: Sucesso
# Código: 11984, Nome: FDI - Portugal - Manufacture of other transportati, Registros: 0, Status: Sucesso
# Código: 11986, Nome: FDI - United kingdom - Manufacture of wood product, Registros: 0, Status: Sucesso
# Código: 11987, Nome: FDI - United kingdom - Forestry, forest exploratio, Registros: 0, Status: Sucesso
# Código: 11988, Nome: FDI - Dominican republic - Transportation ancillar, Registros: 0, Status: Sucesso
# Código: 11990, Nome: FDI - Saint Lucia - Wholesale and commerce interme, Registros: 0, Status: Sucesso
# Código: 11991, Nome: FDI - Saint Lucia - Total, Registros: 0, Status: Sucesso
# Código: 11993, Nome: FDI - Sweden - Manufacture of eletronic materials , Registros: 0, Status: Sucesso
# Código: 11996, Nome: FDI - Switzerland - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 12000, Nome: FDI - Venezuela - Basic metallurgy, Registros: 0, Status: Sucesso
# Código: 12040, Nome: FDI - Bolivia - Manufacture of food and beverages, Registros: 0, Status: Sucesso
# Código: 12042, Nome: FDI - China, people's republic of - Manufacture of, Registros: 0, Status: Sucesso
# Código: 12043, Nome: FDI - South Korea - Manufacture of tobacco product, Registros: 0, Status: Sucesso
# Código: 12044, Nome: FDI - United Arab Emirates - Retail and repair of , Registros: 0, Status: Sucesso
# Código: 12045, Nome: FDI - Slovenia, republic of - Manufacture of eletr, Registros: 0, Status: Sucesso
# Código: 12046, Nome: FDI - Hong-Kong - Manufacture of furniture and oth, Registros: 0, Status: Sucesso
# Código: 12047, Nome: FDI - India - Manufacture of machines and equipmen, Registros: 0, Status: Sucesso
# Código: 12050, Nome: FDI - Turkey - Wholesale and commerce intermediati, Registros: 0, Status: Sucesso
# Código: 12054, Nome: FDI - Israel - Financial intermediation, Registros: 0, Status: Sucesso
# Código: 12055, Nome: FDI - Lebanon - Manufacture of food and beverages, Registros: 0, Status: Sucesso
# Código: 12056, Nome: FDI - Russia - Forestry, forest exploration and re, Registros: 0, Status: Sucesso
# Código: 12057, Nome: FDI - Switzerland - Petroleum extraction and relat, Registros: 0, Status: Sucesso
# Código: 12060, Nome: FDI - Uruguay - Education, Registros: 0, Status: Sucesso
# Código: 12523, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12523/dados?formato=json
# Código: 12524, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12524/dados?formato=json
# Código: 12525, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12525/dados?formato=json
# Código: 12526, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12526/dados?formato=json
# Código: 12527, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12527/dados?formato=json
# Código: 12528, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12528/dados?formato=json
# Código: 12529, Nome: Gross Domestic Product at current prices (Ref. 200, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12529/dados?formato=json
# Código: 12530, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12530/dados?formato=json
# Código: 12531, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12531/dados?formato=json
# Código: 12532, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12532/dados?formato=json
# Código: 12533, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12533/dados?formato=json
# Código: 12534, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12534/dados?formato=json
# Código: 12535, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12535/dados?formato=json
# Código: 12536, Nome: Gross Domestic Product per capita at current price, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12536/dados?formato=json
# Código: 12537, Nome: Formal employment level, Acre, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12537/dados?formato=json
# Código: 12538, Nome: Formal employment level, Amapá, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12538/dados?formato=json
# Código: 12539, Nome: Formal employment level, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12539/dados?formato=json
# Código: 12540, Nome: Formal employment level, Pará, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12540/dados?formato=json
# Código: 12541, Nome: Formal employment level, Rondônia, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12541/dados?formato=json
# Código: 12542, Nome: Formal employment level, Roraima, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12542/dados?formato=json
# Código: 12543, Nome: Formal employment level, Tocantins, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12543/dados?formato=json
# Código: 12544, Nome: Consumer Confidence Index, RS, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12544/dados?formato=json
# Código: 12554, Nome: Real industrial sales (former methodology), Pernam, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12554/dados?formato=json
# Código: 12555, Nome: Installed capacity utilization (former methodology, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12555/dados?formato=json
# Código: 12556, Nome: Hours worked in production (former methodology)- P, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12556/dados?formato=json
# Código: 12561, Nome: Industrial employment (former methodology)- Pernam, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12561/dados?formato=json
# Código: 12562, Nome: Industry real overall wages (former methodology), , Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12562/dados?formato=json
# Código: 12615, Nome: Formal employment level, Paraná, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12615/dados?formato=json
# Código: 12622, Nome: Formal employment level, Santa Catarina, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12622/dados?formato=json
# Código: 12632, Nome: Population - Rio Grande do Sul, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12632/dados?formato=json
# Código: 12640, Nome: Formal employment level, Pernambuco, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12640/dados?formato=json
# Código: 12641, Nome: Formal employment level, Paraíba, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12641/dados?formato=json
# Código: 12642, Nome: Formal employment level, Rio Grande do Norte, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12642/dados?formato=json
# Código: 12643, Nome: Formal employment level, Alagoas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12643/dados?formato=json
# Código: 12644, Nome: Formal employment level, Sergipe, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12644/dados?formato=json
# Código: 12677, Nome: Real industrial sales, Acre (jul/04, dec/06), Jun/, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12677/dados?formato=json
# Código: 12679, Nome: Installed capacity utilization, Acre (jul/04, dec/, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12679/dados?formato=json
# Código: 12680, Nome: Industrial employment, Acre (jul/04, dec/06), Jun/, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12680/dados?formato=json
# Código: 12681, Nome: Industry real overall wages, Acre (jul/04, dec/06), Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12681/dados?formato=json
# Código: 12682, Nome: Real industrial sales, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12682/dados?formato=json
# Código: 12683, Nome: Hours worked in production, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12683/dados?formato=json
# Código: 12684, Nome: Installed capacity utilization, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12684/dados?formato=json
# Código: 12685, Nome: Industrial employment, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12685/dados?formato=json
# Código: 12686, Nome: Industry real overall wages, Amazonas, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12686/dados?formato=json
# Código: 12688, Nome: Population - Acre, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12688/dados?formato=json
# Código: 12689, Nome: Population - Amapá, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12689/dados?formato=json
# Código: 12690, Nome: Population - Amazonas, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12690/dados?formato=json
# Código: 12691, Nome: Population - Pará, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12691/dados?formato=json
# Código: 12692, Nome: Population - Rondônia, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12692/dados?formato=json
# Código: 12693, Nome: Population - Roraima, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12693/dados?formato=json
# Código: 12694, Nome: Population - Tocantins, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12694/dados?formato=json
# Código: 12730, Nome: Unemployed people, Metropolitan Region of Recife, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12730/dados?formato=json
# Código: 12733, Nome: Economically active population, Metropolitan Regio, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12733/dados?formato=json
# Código: 12735, Nome: Real average earnings of occupied people, metropol, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12735/dados?formato=json
# Código: 12747, Nome: Consumer purchase expectation index, global, Macei, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12747/dados?formato=json
# Código: 12748, Nome: Consumer purchase expectation index, current, Mace, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12748/dados?formato=json
# Código: 12749, Nome: Consumer purchase expectation index, future, Macei, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12749/dados?formato=json
# Código: 12756, Nome: Real industrial sales, Paraná (former methodology), Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12756/dados?formato=json
# Código: 12769, Nome: Hours worked in industrial production, Paraná (for, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12769/dados?formato=json
# Código: 12775, Nome: Industry real overall wages, Paraná (former method, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12775/dados?formato=json
# Código: 12777, Nome: Industrial employment, Paraná (former methodology), Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12777/dados?formato=json
# Código: 12779, Nome: Formal employment level, Rio de Janeiro, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12779/dados?formato=json
# Código: 12781, Nome: Formal employment level, Espírito Santo, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12781/dados?formato=json
# Código: 12796, Nome: Population, Paraná, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12796/dados?formato=json
# Código: 12799, Nome: Population - Santa Catarina, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12799/dados?formato=json
# Código: 12831, Nome: Population - São Paulo, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12831/dados?formato=json
# Código: 12868, Nome: Formal employment level, São Paulo, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12868/dados?formato=json
# Código: 12975, Nome: Financial system provision by risk level, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12975/dados?formato=json
# Código: 12976, Nome: Financial institutions under public control provis, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12976/dados?formato=json
# Código: 12977, Nome: Financial institutions under private control provi, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12977/dados?formato=json
# Código: 12978, Nome: Financial institutions under national private cont, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12978/dados?formato=json
# Código: 12979, Nome: Financial institutions under foreign control provi, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12979/dados?formato=json
# Código: 12980, Nome: Population - Bahia, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.12980/dados?formato=json
# Código: 13088, Nome: Installed capacity utilization, PR (former methodo, Registros: 0, Status: Erro de requisição: Expecting value: line 1 column 1 (char 0)
# Código: 13103, Nome: Formal employment level, Rio Grande do Sul, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13103/dados?formato=json
# Código: 13121, Nome: Population - Minas Gerais, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13121/dados?formato=json
# Código: 13122, Nome: Population - Goiás, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13122/dados?formato=json
# Código: 13123, Nome: Population - Mato Grosso, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13123/dados?formato=json
# Código: 13124, Nome: Population - Mato Grosso do Sul, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13124/dados?formato=json
# Código: 13125, Nome: Population - Distrito Federal, Registros: 0, Status: Erro de requisição: 403 Client Error: Forbidden for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13125/dados?formato=json
# Código: 13141, Nome: Formal employment level, Ceará, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13141/dados?formato=json
# Código: 13142, Nome: Formal employment level, Maranhão, Registros: 0, Status: Erro de requisição: 400 Client Error: Bad Request for url: https://api.bcb.gov.br/dados/serie/bcdata.sgs.13142/dados?formato=json
# ...
# Código: 8620, Nome: FDI, Chile, Retail and repair of articles, 8620, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8621, Nome: FDI, Chile, Mail and telecommunications, 8621, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8622, Nome: FDI, Chile, Publishing, printing and reproduction , de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8623, Nome: FDI, Chile, Eletricity, gas and hot water, 8623, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8624, Nome: FDI, Chile, Petroleum extraction and related servi, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8625, Nome: FDI, Chile, Manufacture of rubber and plastic arti, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8626, Nome: FDI, Chile, Manufacture of cellulose, paper and pa, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8627, Nome: FDI, Chile, Manufacture of machines and equipment,, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8628, Nome: FDI, Chile, Manufacture of eletric machines, appar, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8629, Nome: FDI, Chile, Manufacture of wood products, 8629, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 863, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3162, Status: Sucesso
# Código: 8630, Nome: FDI, Chile, Manufacture of metal products, 8630, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8631, Nome: FDI, Chile, Manufacture of chemical products, 8631, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8633, Nome: FDI, Chile, Services redered to companies, 8633, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8634, Nome: FDI, China, People's Republic of, Total, 8634, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8635, Nome: FDI, China, People's Republic of, Commerce and rep, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8636, Nome: FDI, China, People's Republic of, Wholesale and co, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8637, Nome: FDI, China, People's Republic of, Construction, 86, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8638, Nome: FDI, China, People's Republic of, Extraction of or, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8639, Nome: FDI, China, People's Republic of, Manufacture of r, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 864, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3162, Status: Sucesso
# Código: 8640, Nome: FDI, China, People's Republic of, Manufacture of m, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8641, Nome: FDI, China, People's Republic of, Manufacture of w, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8642, Nome: FDI, China, People's Republic of, Fishing, water f, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8643, Nome: FDI, China, People's Republic of, Services redered, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8644, Nome: FDI, Cyprus, Total, 8644, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8645, Nome: FDI, Cyprus, Wholesale and commerce intermediation, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8646, Nome: FDI, Cyprus, Mail and telecommunications, 8646, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8647, Nome: FDI, Cyprus, Financial intermediation, 8647, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8648, Nome: FDI, Singapore, Total, 8648, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8649, Nome: FDI, Singapore, Real estate activities, 8649, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 865, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3161, Status: Sucesso
# Código: 8650, Nome: FDI, Singapore, Wholesale and commerce intermediat, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8651, Nome: FDI, Singapore, Manufacture of machines and equipm, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8652, Nome: FDI, Singapore, Manufacture of office machines and, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8654, Nome: FDI, Singapore, Manufacture of tobacco products, 8, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8655, Nome: FDI, Singapore, Manufacture of chemical products, , de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8656, Nome: FDI, Singapore, Basic metallurgy, 8656, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8657, Nome: FDI, Singapore, Recycling, 8657, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8658, Nome: FDI, Singapore, Services redered to companies, 865, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8659, Nome: FDI, Colombia, Total, 8659, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 866, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3161, Status: Sucesso
# Código: 8660, Nome: FDI, Colombia, Wholesale and commerce intermediati, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8661, Nome: FDI, Colombia, Retail and repair of articles, 8661, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8662, Nome: FDI, Colombia, Construction, 8662, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8663, Nome: FDI, Colombia, Publishing, printing and reproducti, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8664, Nome: FDI, Colombia, Manufacture of rubber and plastic a, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8665, Nome: FDI, Colombia, Manufacture and assembly of motor v, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8666, Nome: FDI, Colombia, Fishing, water farming and related , de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8667, Nome: FDI, Colombia, Services redered to companies, 8667, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8668, Nome: FDI, Cook Islands, Total, 8668, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8669, Nome: FDI, Cook Islands, Real estate activities, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 867, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3162, Status: Sucesso
# Código: 8670, Nome: FDI, Cook Islands, Services redered to companies, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8671, Nome: FDI, South Korea, Total, 8671, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8672, Nome: FDI, South Korea, Wholesale and commerce intermedi, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8673, Nome: FDI, South Korea, Construction, 8673, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8674, Nome: FDI, South Korea, Petroleum extraction and related, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8675, Nome: FDI, South Korea, Manufacture of machines and equi, Registros: 0, Status: Erro de requisição: Expecting value: line 1 column 1 (char 0)
# Código: 8676, Nome: FDI, South Korea, Manufacture of eletric machines,, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8677, Nome: FDI, South Korea, Manufacture of eletronic materia, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8678, Nome: FDI, South Korea, Manufacture of metal products, 8, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8679, Nome: FDI, South Korea, Manufacture of textiles, 8679, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 868, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-06-01 00:00:00, a: 2012-12-01 00:00:00, Registros: 151, Status: Sucesso
# Código: 8680, Nome: FDI, South Korea, Financial intermediation, 8680, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8681, Nome: FDI, South Korea, Basic metallurgy, 8681, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8682, Nome: FDI, South Korea, Services redered to companies, 8, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8683, Nome: FDI, Costa Rica, Total, 8683, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8684, Nome: FDI, Costa Rica, Manufacture of cellulose, paper a, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8685, Nome: FDI, Costa Rica, Manufacture of chemical products,, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8686, Nome: FDI, Costa Rica, Services redered to companies, 86, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8687, Nome: FDI, Cuba, Total, 8687, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8688, Nome: FDI, Cuba, Manufacture of chemical products, 8688, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8689, Nome: FDI, Cuba, Services redered to companies, 8689, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 869, Nome: Credit operations with nonearmarked funds (floatin, de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3161, Status: Sucesso
# Código: 8690, Nome: FDI, Denmark, Total, 8690, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8691, Nome: FDI, Denmark, Financial intermediation ancillary a, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8692, Nome: FDI, Denmark, Data processing and related activiti, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8693, Nome: FDI, Denmark, Wholesale and commerce intermediatio, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8694, Nome: FDI, Denmark, Retail and repair of articles, 8694, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8695, Nome: FDI, Denmark, Construction, 8695, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8696, Nome: FDI, Denmark, Petroleum extraction and related ser, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8697, Nome: FDI, Denmark, Manufacture of cellulose, paper and , de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8698, Nome: FDI, Denmark, Manufacture of medical, precision ap, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8699, Nome: FDI, Denmark, Manufacture of machines and equipmen, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 87, Nome: Credit operations with nonearmarked funds (postset, de: 1994-07-04 00:00:00, a: 2012-12-31 00:00:00, Registros: 4641, Status: Sucesso
# Código: 870, Nome: Credit operations with nonearmarked funds (preset , de: 2000-05-31 00:00:00, a: 2012-12-31 00:00:00, Registros: 3162, Status: Sucesso
# Código: 8700, Nome: FDI, Denmark, Manufacture of eletronic materials a, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8701, Nome: FDI, Denmark, Manufacture of food and beverages, 8, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8702, Nome: FDI, Denmark, Manufacture of wood products, 8702, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8703, Nome: FDI, Denmark, Manufacture of chemical products, 87, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8705, Nome: FDI, Denmark, Services redered to companies, 8705, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8706, Nome: FDI, United Arab Emirates, Total, 8706, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8707, Nome: FDI, United Arab Emirates, Services redered to com, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8708, Nome: FDI, Ecuador, Total, 8708, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8709, Nome: FDI, Ecuador, Transportation ancillary activities , de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 871, Nome: Credit operations with nonearmarked funds (preset , de: 2000-06-01 00:00:00, a: 2012-12-01 00:00:00, Registros: 151, Status: Sucesso
# Código: 8710, Nome: FDI, Ecuador, Wholesale and commerce intermediatio, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8711, Nome: FDI, Ecuador, Construction, 8711, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8712, Nome: FDI, Ecuador, Fishing, water farming and related s, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8713, Nome: FDI, Ecuador, Preparation of leather and articles , de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8714, Nome: FDI, Slovenia, republic of, Total, de: 1997-01-01 00:00:00, a: 2003-01-01 00:00:00, Registros: 7, Status: Sucesso
# Código: 8716, Nome: FDI, Spain, Total, 8716, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8717, Nome: FDI, Spain, Public administration, defense and soc, de: 1997-01-01 00:00:00, a: 2002-01-01 00:00:00, Registros: 6, Status: Sucesso
# Código: 8718, Nome: FDI, Spain, Agriculture, livestock and related ser, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 8719, Nome: FDI, Spain, Accomodation and catering, 8719, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Código: 872, Nome: Credit operations with nonearmarked funds (preset , de: 2000-06-01 00:00:00, a: 2012-12-01 00:00:00, Registros: 151, Status: Sucesso
# Código: 8720, Nome: FDI, Spain, Rental of vehicles, machines, equipmen, de: 1997-01-01 00:00:00, a: 2004-01-01 00:00:00, Registros: 8, Status: Sucesso
# Processo concluído e metadados atualizados.

# %%
import pandas as pd

# Caminho do arquivo CSV atualizado
file_path = 'BCB_metadata_atualizado.csv'

# Carregar o arquivo de metadados
metadata_df = pd.read_csv(file_path, sep=',', quotechar='"', on_bad_lines='skip')

# Filtrar registros que tiveram sucesso no download e estão ativos
# Considera-se que o status do download foi "Sucesso" e o status de atividade é "Ativa"
ativos_df = metadata_df[
    #(metadata_df['status_download'] == 'Sucesso') &
    (metadata_df['status_atividade'] == 'Ativa')
]

# Ordenar os registros filtrados pelo campo 'código' como inteiro
ativos_df = ativos_df.sort_values(by='código')

# Exibir os registros filtrados
if not ativos_df.empty:
    print("Registros ativos e com download bem-sucedido:")
else:
    print("Nenhum registro ativo encontrado com download bem-sucedido.")
# Out:
# Registros ativos e com download bem-sucedido:

# %%
ativos_df
# Out:
#       código                                               nome  \
# 0          1  Exchange rate, Free, United States dollar (sal...
# 916       11                               Interest rate, Selic
# 1882      12                                 Interest rate, CDI
# 5702      23  Daily savings deposits balance, Brazilian syst...
# 5810      24  Daily saving deposits net inflow, Brazilian sy...
# ...      ...                                                ...
# 4670   20359   Foreign exchange interbank spot volume, USD, T+1
# 4722   20479        Claims on Other Sectors, Monetary Authority
# 4725   20499                         Assets, Monetary Authority
# 4727   20500                      Liability, Monetary Authority
# 5487   21379  Broad national consumer price index (IPCA) - D...
#
#                                               descrição        atualizado_em  \
# 0     Exchange rate, Free, United States dollar (sal...  2024-09-15 15:54:06
# 916                               Interest rate, Selic.  2024-09-15 16:11:42
# 1882                                Interest rate, CDI.  2024-09-15 16:32:27
# 5702  Daily savings deposits balance, Brazilian syst...  2024-09-15 17:40:18
# 5810  Daily saving deposits net inflow, Brazilian sy...  2024-09-15 17:41:58
# ...                                                 ...                  ...
# 4670  Foreign exchange interbank spot volume, USD, T+1.  2024-09-15 17:22:22
# 4722       Claims on Other Sectors, Monetary Authority.  2024-09-15 17:23:30
# 4725                        Assets, Monetary Authority.  2024-09-15 17:23:33
# 4727                     Liability, Monetary Authority.  2024-09-15 17:23:35
# 5487  Broad national consumer price index (IPCA) - D...  2024-09-15 17:36:50
#
#                 Unidade  num_registros primeira_data ultima_data  \
# 0            c.m.u./US$         9972.0    1984-11-28  2024-09-13
# 916              % p.d.         9597.0    1986-06-04  2024-09-13
# 1882             % p.d.         9638.0    1986-03-06  2024-09-12
# 5702  c.m.u. (thousand)         8275.0    1991-08-22  2024-08-15
# 5810  c.m.u. (thousand)         8275.0    1991-08-22  2024-08-15
# ...                 ...            ...           ...         ...
# 4670                US$         7581.0    1994-07-04  2024-09-13
# 4722   c.m.u. (million)          237.0    2004-12-01  2024-08-01
# 4725   c.m.u. (million)          237.0    2004-12-01  2024-08-01
# 4727   c.m.u. (million)          237.0    2004-12-01  2024-08-01
# 5487                  %          300.0    1999-09-01  2024-08-01
#
#       intervalo_dias     valor_min     valor_max   media_valor  \
# 0                2.0  8.290000e-01  7.115300e+04  8.484459e+02
# 916              2.0  0.000000e+00  3.626000e+00  2.589656e-01
# 1882             3.0  7.469000e-03  3.970667e+00  2.631420e-01
# 5702            31.0  3.294983e+07  1.579828e+12  1.651508e+10
# 5810            31.0 -4.012215e+09  5.833764e+09  2.019914e+07
# ...              ...           ...           ...           ...
# 4670             2.0  0.000000e+00  7.728700e+09  4.543453e+08
# 4722            45.0  0.000000e+00  1.170000e+03  3.563291e+01
# 4725            45.0  1.949230e+05  3.046324e+06  1.406689e+06
# 4727            45.0  1.949230e+05  3.046324e+06  1.406689e+06
# 5487            45.0  4.182000e+01  8.594000e+01  6.150743e+01
#
#       desvio_padrao_valor  media_frequencia frequencia status_atividade  \
# 0            4.693352e+03          1.457481     Diária            Ativa
# 916          4.751020e-01          1.456809     Diária            Ativa
# 1882         4.818885e-01          1.459846     Diária            Ativa
# 5702         1.111415e+11          1.455831     Diária            Ativa
# 5810         2.742354e+08          1.455831     Diária            Ativa
# ...                   ...               ...        ...              ...
# 4670         5.904142e+08          1.454821     Diária            Ativa
# 4722         1.824131e+02         30.308017     Mensal            Ativa
# 4725         7.871805e+05         30.308017     Mensal            Ativa
# 4727         7.871805e+05         30.308017     Mensal            Ativa
# 5487         7.314307e+00         30.336667     Mensal            Ativa
#
#      status_download
# 0                NaN
# 916              NaN
# 1882             NaN
# 5702             NaN
# 5810             NaN
# ...              ...
# 4670             NaN
# 4722             NaN
# 4725             NaN
# 4727             NaN
# 5487             NaN
#
# [331 rows x 17 columns]

# %%
# Salvar os registros filtrados em um novo arquivo, se necessário
ativos_df.to_csv('BCB_metadata_active.csv', index=False)  # Caso queira salvar os ativos
